# %%
import pickle
import operator

# %%
carbA=[6,41,53]
carbB=[9,10,23,24,25,34,36,42,44,50,11]

def getDistance(lat1,lon1,lat2,lon2):
    from math import sin, cos, sqrt, atan2, radians

    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c

    return distance

# %%
target='Com'
endyear=2017

# %%
G=pickle.load(open('{}/Graph.pickle'.format(target),"rb"))
waveMatrix=pickle.load(open('{}/waveMatrix.pickle'.format(target),"rb"))
skip=pickle.load(open('{}/skip.pickle'.format(target),"rb"))
nodeNames=pickle.load(open('{}/Correlations/o3/{}/nodeNames.pickle'.format(target,endyear),"rb"))
networkDetails=open('{}/CorrelationSummary/networkfeautures.csv'.format(target),'r').readline().strip().split(',')
locations=pickle.load(open('locations.pickle',"rb"))

# %%
data={}
data2={}
for i in range(len(waveMatrix)):
        for j in range(i+1,len(waveMatrix)):
                node1 = nodeNames[i]
                node2 = nodeNames[j]
                if node1 not in skip and node2 not in skip:
#                     if (int(node1.split('-')[0]) in carbA and int(node2.split('-')[0]) in carbB) \
#                     or (int(node1.split('-')[0]) in carbB and int(node2.split('-')[0]) in carbA):
#                     if (int(node1.split('-')[0]) in carbA+carbB and int(node2.split('-')[0]) not in carbA+carbB) \
#                     or (int(node1.split('-')[0]) not in carbA+carbB and int(node2.split('-')[0]) in carbB+carbA):
                      x=locations[node1]
                      y=locations[node2]
                      distance=getDistance(x[0],x[1],y[0],y[1])
                      data[node1+'/'+node2]=(waveMatrix[i][j]+1)**3+(distance**0.2)
                      data2[node1+'/'+node2]=waveMatrix[i][j]

# %%
sorted(data.items(),key=operator.itemgetter(1),reverse=True)
# Out:
# [('24-5-3001/42-101-24', 9.5470832225419411),
#  ('24-5-3001/42-45-2', 9.4519716199884591),
#  ('17-111-1/17-201-2001', 9.4496591350170362),
#  ('42-17-12/42-45-2', 9.4317972427650325),
#  ('24-5-1007/42-101-24', 9.4229852944150494),
#  ('17-143-1001/17-201-2001', 9.3710331561882647),
#  ('24-25-1001/42-45-2', 9.3567490095725265),
#  ('42-101-24/42-133-8', 9.3562511068446224),
#  ('6-37-2/6-71-1004', 9.3541787711290425),
#  ('42-101-24/42-71-7', 9.3536804907057736),
#  ('42-133-8/42-91-13', 9.3517980758987509),
#  ('42-133-8/42-17-12', 9.3504733821784161),
#  ('24-5-1007/42-91-13', 9.3492634799937111),
#  ('42-17-12/42-71-7', 9.3485904413997432),
#  ('24-25-1001/42-101-24', 9.3471859149575725),
#  ('34-19-1/34-27-3001', 9.3432444413596549),
#  ('42-133-8/42-45-2', 9.3398666793210019),
#  ('42-71-7/42-91-13', 9.3358503186302588),
#  ('24-5-1007/42-45-2', 9.333882032679119),
#  ('42-133-8/42-71-7', 9.3264141215100302),
#  ('34-19-1/42-133-8', 9.3260839919713643),
# ...

# %%
# CARB-A CARB-B
('24-5-3001/6-71-1', 0.60667234556740657),
 ('42-101-24/6-71-1', 0.59138730657869609)
    
('24-5-3001/51-13-20', 0.88765104663145233),
 ('24-31-3001/51-13-20', 0.87946262128005215)
    
17-143-1001/17-143-24', 0.9610001247554909),
 ('6-37-2/6-71-1004', 0.95005381584515225),
 ('6-65-8001/6-71-1004', 0.94466962164658574

# %%
data2['24-5-3001/6-71-1']
24-5-3001/6-71-1
# Out:
# 0.60667234556740657

# %%
data2['42-101-24/6-71-1']
# Out:
# 0.59138730657869609

# %%
data2['24-5-3001/42-101-24']
# Out:
# 0.8962060259712904

# %%
x,y=locations['24-5-3001'],locations['42-101-24']
getDistance(x[0],x[1],y[0],y[1])
# Out:
# 151.38723799793388

# %%
# Q2

population=0
f=open('NA/files/NA2014-2016.tsv','r')
for l in f:
    row=l.strip().split('\t')
    population+=int(row[-1].replace(',',''))

# %%
population
# Out:
# 124069378
